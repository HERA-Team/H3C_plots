# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import matplotlib.patches as mpatches
import matplotlib.gridspec as gridspec
import numpy as np
from pyuvdata import UVCal, UVData, utils
import os
import sys
import glob
import uvtools as uvt
from astropy.time import Time
from astropy.coordinates import EarthLocation, SkyCoord, AltAz, Angle
import pandas
import warnings 
import copy
import utils
import hera_qm
from hera_mc import cm_hookup
warnings.filterwarnings('ignore')
# Out:
# could not import sklearn

# %%
# get data location
#data_path = os.environ['DATA_PATH']
#JD = os.environ['JULIANDATE']
data_path = '/lustre/aoc/projects/hera/lberkhou/2458848/'
JD = '2458848'
jd = 2458848

# %%
# Load in data
HHfiles, difffiles, uvdx, uvdy, uvd1, uvd2 = utils.load_data(data_path,JD)
# Out:
# ############################################################
# ######### DIFFERENT NUMBER OF SUM AND DIFF FILES ###########
# ############################################################

# %% [markdown]
# ## Autocorrelations for a single file

# %% [markdown]
# This plot shows autocorrelations for one timestamp of each antenna that is active and each polarization

# %%
### plot autos
utils.plot_autos(uvdx, uvdy, uvd1, uvd2)

# %% [markdown]
# ## Waterfalls of Autocorrelation Amplitudes for each Antenna and Each polarization

# %%
uvd = UVData()
uvd.read_uvh5(HHfiles, ant_str = 'autos')
lst0 = np.min(uvd1.lst_array) 
lst1 = np.max(uvd2.lst_array)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-9e54d0e1eea8> in <module>
#       1 uvd = UVData()
# ----> 2 uvd.read_uvh5(HHfiles, ant_str = 'autos')
#       3 lst0 = np.min(uvd1.lst_array)
#       4 lst1 = np.max(uvd2.lst_array)
#
# /lustre/aoc/projects/hera/lberkhou/miniconda3/envs/nightlynb/lib/python3.6/site-packages/pyuvdata/uvdata.py in read_uvh5(self, filename, axis, antenna_nums, antenna_names, ant_str, bls, frequencies, freq_chans, times, polarizations, blt_inds, keep_all_metadata, read_data, data_array_dtype, run_check, check_extra, run_check_acceptability)
#    3053                                   run_check_acceptability=run_check_acceptability,
#    3054                                   data_array_dtype=data_array_dtype,
# -> 3055                                   keep_all_metadata=keep_all_metadata)
#    3056                     if axis is not None:
#    3057                         self.fast_concat(uv2, axis, run_check=run_check,
#
# /lustre/aoc/projects/hera/lberkhou/miniconda3/envs/nightlynb/lib/python3.6/site-packages/pyuvdata/uvdata.py in read_uvh5(self, filename, axis, antenna_nums, antenna_names, ant_str, bls, frequencies, freq_chans, times, polarizations, blt_inds, keep_all_metadata, read_data, data_array_dtype, run_check, check_extra, run_check_acceptability)
#    3071                                run_check_acceptability=run_check_acceptability,
#    3072                                data_array_dtype=data_array_dtype,
# -> 3073                                keep_all_metadata=keep_all_metadata)
#    3074             self._convert_from_filetype(uvh5_obj)
#    3075             del(uvh5_obj)
#
# /lustre/aoc/projects/hera/lberkhou/miniconda3/envs/nightlynb/lib/python3.6/site-packages/pyuvdata/uvh5.py in read_uvh5(self, filename, antenna_nums, antenna_names, ant_str, bls, frequencies, freq_chans, times, polarizations, blt_inds, read_data, run_check, check_extra, run_check_acceptability, data_array_dtype, keep_all_metadata)
#     486         """
#     487         if not os.path.exists(filename):
# --> 488             raise IOError(filename + ' not found')
#     489
#     490         if not read_data:
#
# OSError: /lustre/aoc/projects/hera/lberkhou/2458848/zen.2458848.52822.uvh5 not found

# %%
utils.plot_wfs(uvd, pol = 1)

# %%
utils.plot_wfs(uvd, pol = 0)

# %% [markdown]
# ## Correlation Metrics

# %% [markdown]
# The first plot shows the correlation metric (described below) for a set of baseline types, as calculated at several times throughout the night. It is expected that longer baselines (darker color) will exhibit lower values than the short baselines.
#
# The matrices show the phase correlation between antennas. Using the even and odd visibilities, each pixel is calculated as (even/abs(even)) * (conj(odd)/abs(odd)), and then averaged across time and frequency. If the phases are noise-like, this value will average down to zero. If the antennas are well correlated, the phases should not be noise-like, and this value should average to 1. The lines denoting node boundaries are intended to help confirm that inter-node correlations are functioning - if they aren't, this plot will appear block-diagonal.
#
# This metric has shown to be LST locked - when comparing to other nights, be sure to compare for the same LST. It is expected that some LSTs will look much better or worse than others.
#
# Note: Within each node, the order of antennas is determined by snap, and within that by snap input number.

# %%
badAnts = []
badAnts = utils.plotNodeAveragedSummary(uvd1,HHfiles)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-460139691388> in <module>
#       1 badAnts = []
# ----> 2 badAnts = utils.plotNodeAveragedSummary(uvd1,HHfiles)
#
# /lustre/aoc/projects/hera/lberkhou/H3C_plots/utils.py in plotNodeAveragedSummary(uv, HHfiles, pols, baseline_groups, removeBadAnts)
#     242     maxLength = 0
#     243     cmap = plt.get_cmap('Blues')
# --> 244     nodeMedians,lsts,badAnts=get_correlation_baseline_evolutions(uv,HHfiles,bl_type=baseline_groups,removeBadAnts=removeBadAnts)
#     245     for group in baseline_groups:
#     246         if group[0] > maxLength:
#
# /lustre/aoc/projects/hera/lberkhou/H3C_plots/utils.py in get_correlation_baseline_evolutions(uv, HHfiles, badThresh, pols, bl_type, removeBadAnts, plotMatrix)
#     482         sm = UVData()
#     483         df = UVData()
# --> 484         sm.read_uvh5(file)
#     485         df.read_uvh5('%s.diff%s' % (file[0:-5],file[-5:]))
#     486         matrix, badAnts = calcEvenOddAmpMatrix(sm,df,nodes='auto',badThresh=badThresh)
#
# /lustre/aoc/projects/hera/lberkhou/miniconda3/envs/nightlynb/lib/python3.6/site-packages/pyuvdata/uvdata.py in read_uvh5(self, filename, axis, antenna_nums, antenna_names, ant_str, bls, frequencies, freq_chans, times, polarizations, blt_inds, keep_all_metadata, read_data, data_array_dtype, run_check, check_extra, run_check_acceptability)
#    3071                                run_check_acceptability=run_check_acceptability,
#    3072                                data_array_dtype=data_array_dtype,
# -> 3073                                keep_all_metadata=keep_all_metadata)
#    3074             self._convert_from_filetype(uvh5_obj)
#    3075             del(uvh5_obj)
#
# /lustre/aoc/projects/hera/lberkhou/miniconda3/envs/nightlynb/lib/python3.6/site-packages/pyuvdata/uvh5.py in read_uvh5(self, filename, antenna_nums, antenna_names, ant_str, bls, frequencies, freq_chans, times, polarizations, blt_inds, read_data, run_check, check_extra, run_check_acceptability, data_array_dtype, keep_all_metadata)
#     486         """
#     487         if not os.path.exists(filename):
# --> 488             raise IOError(filename + ' not found')
#     489
#     490         if not read_data:
#
# OSError: /lustre/aoc/projects/hera/lberkhou/2458848/zen.2458848.29066.uvh5 not found

# %% [markdown]
# Visibility amplitude spectra for a set of redundant baselines, labeled by inter vs. intranode baselines. The red and blue should exhibit the same bandpass shape - if the red are consistently different from the blue, this indicates an issue with internode correlations.
#
# Note: antennas that were identified as bad by the correlation matrix have been removed from this plot.

# %%
utils.plotVisibilitySpectra(HHfiles[len(HHfiles)//2], badAnts=badAnts)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-0899912e6f29> in <module>
# ----> 1 utils.plotVisibilitySpectra(HHfiles[len(HHfiles)//2], badAnts=badAnts)
#
# /lustre/aoc/projects/hera/lberkhou/H3C_plots/utils.py in plotVisibilitySpectra(file, badAnts, length, pols, clipLowAnts)
#     268     plt.subplots_adjust(wspace=0.25)
#     269     uv = UVData()
# --> 270     uv.read_uvh5(file)
#     271     h = cm_hookup.Hookup()
#     272     x = h.get_hookup('HH')
#
# /lustre/aoc/projects/hera/lberkhou/miniconda3/envs/nightlynb/lib/python3.6/site-packages/pyuvdata/uvdata.py in read_uvh5(self, filename, axis, antenna_nums, antenna_names, ant_str, bls, frequencies, freq_chans, times, polarizations, blt_inds, keep_all_metadata, read_data, data_array_dtype, run_check, check_extra, run_check_acceptability)
#    3071                                run_check_acceptability=run_check_acceptability,
#    3072                                data_array_dtype=data_array_dtype,
# -> 3073                                keep_all_metadata=keep_all_metadata)
#    3074             self._convert_from_filetype(uvh5_obj)
#    3075             del(uvh5_obj)
#
# /lustre/aoc/projects/hera/lberkhou/miniconda3/envs/nightlynb/lib/python3.6/site-packages/pyuvdata/uvh5.py in read_uvh5(self, filename, antenna_nums, antenna_names, ant_str, bls, frequencies, freq_chans, times, polarizations, blt_inds, read_data, run_check, check_extra, run_check_acceptability, data_array_dtype, keep_all_metadata)
#     486         """
#     487         if not os.path.exists(filename):
# --> 488             raise IOError(filename + ' not found')
#     489
#     490         if not read_data:
#
# OSError: /lustre/aoc/projects/hera/lberkhou/2458848/zen.2458848.46358.uvh5 not found

# %% [markdown]
# ## Antenna Positions

# %% [markdown]
# Antennas outlined in black here have been identified by the correlation matrix as bad antennas.

# %%
utils.plot_antenna_positions(uvd1, badAnts=badAnts)

# %% [markdown]
# ## Single File Antenna Metrics

# %%
antmetfiles = sorted(glob.glob("{0}/zen.*.*.hdf5".format(data_path)))
ant_metrics = hera_qm.ant_metrics.load_antenna_metrics(antmetfiles[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-aef7219d6982> in <module>
#       1 antmetfiles = sorted(glob.glob("{0}/zen.*.*.hdf5".format(data_path)))
# ----> 2 ant_metrics = hera_qm.ant_metrics.load_antenna_metrics(antmetfiles[1])
#
# IndexError: list index out of range

# %%
utils.show_metric(ant_metrics, antmetfiles, ants=None, antpols=None, title='', ylabel='Modified z-Score', xlabel='')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-02d2573abc06> in <module>
# ----> 1 utils.show_metric(ant_metrics, antmetfiles, ants=None, antpols=None, title='', ylabel='Modified z-Score', xlabel='')
#
# NameError: name 'ant_metrics' is not defined

# %% [markdown]
# ## Ant Metrics over a whole night

# %%
utils.all_ant_mets(antmetfiles, HHfiles)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-d693b7eeb097> in <module>
# ----> 1 utils.all_ant_mets(antmetfiles, HHfiles)
#
# /lustre/aoc/projects/hera/lberkhou/H3C_plots/utils.py in all_ant_mets(antmetfiles, HHfiles)
#     717     file = HHfiles[0]
#     718     uvd_hh = UVData()
# --> 719     uvd_hh.read_uvh5(file)
#     720     uvdx = uvd_hh.select(polarizations = -5, inplace = False)
#     721     uvdx.ants = np.unique(np.concatenate([uvdx.ant_1_array, uvdx.ant_2_array]))
#
# /lustre/aoc/projects/hera/lberkhou/miniconda3/envs/nightlynb/lib/python3.6/site-packages/pyuvdata/uvdata.py in read_uvh5(self, filename, axis, antenna_nums, antenna_names, ant_str, bls, frequencies, freq_chans, times, polarizations, blt_inds, keep_all_metadata, read_data, data_array_dtype, run_check, check_extra, run_check_acceptability)
#    3071                                run_check_acceptability=run_check_acceptability,
#    3072                                data_array_dtype=data_array_dtype,
# -> 3073                                keep_all_metadata=keep_all_metadata)
#    3074             self._convert_from_filetype(uvh5_obj)
#    3075             del(uvh5_obj)
#
# /lustre/aoc/projects/hera/lberkhou/miniconda3/envs/nightlynb/lib/python3.6/site-packages/pyuvdata/uvh5.py in read_uvh5(self, filename, antenna_nums, antenna_names, ant_str, bls, frequencies, freq_chans, times, polarizations, blt_inds, read_data, run_check, check_extra, run_check_acceptability, data_array_dtype, keep_all_metadata)
#     486         """
#     487         if not os.path.exists(filename):
# --> 488             raise IOError(filename + ' not found')
#     489
#     490         if not read_data:
#
# OSError: /lustre/aoc/projects/hera/lberkhou/2458848/zen.2458848.25531.uvh5 not found
